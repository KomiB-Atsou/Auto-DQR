# %%
# os.environ["HTTP_PROXY"]  = "http://i025207:1X4kD6IYe3pd@138.21.167.201:3128"
# os.environ["HTTPS_PROXY"] = "http://user:password@proxy_host:proxy_port"


import os
import certifi

PROXY = "http://i025207:1X4kD6IYe3pd@138.21.167.201:3128"
#CA_CERT = "upload.video.google.com"
CA_CERT = r"C:\Users\i025207\Desktop\fullCA.pem"

os.environ["HTTP_PROXY"]  = PROXY
# os.environ["HTTPS_PROXY"] = PROXY

os.environ["SSL_CERT_FILE"] = CA_CERT
os.environ["REQUESTS_CA_BUNDLE"] = CA_CERT
os.environ["GRPC_DEFAULT_SSL_ROOTS_FILE_PATH"] = CA_CERT

# %%
import requests
requests.get("https://www.googleapis.com").status_code
# Out:
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# ~\AppData\Roaming\Python\Python39\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     463             try:
# --> 464                 self._validate_conn(conn)
#     465             except (SocketTimeout, BaseSSLError) as e:
#
# ~\AppData\Roaming\Python\Python39\site-packages\urllib3\connectionpool.py in _validate_conn(self, conn)
#    1092         if conn.is_closed:
# -> 1093             conn.connect()
#    1094
#
# ~\AppData\Roaming\Python\Python39\site-packages\urllib3\connection.py in connect(self)
#     795
# --> 796             sock_and_verified = _ssl_wrap_socket_and_match_hostname(
#     797                 sock=sock,
#
# ...

# %%
requests.get(
    "https://www.googleapis.com/discovery/v1/apis"
).status_code
# Out:
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# ~\AppData\Roaming\Python\Python39\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     463             try:
# --> 464                 self._validate_conn(conn)
#     465             except (SocketTimeout, BaseSSLError) as e:
#
# ~\AppData\Roaming\Python\Python39\site-packages\urllib3\connectionpool.py in _validate_conn(self, conn)
#    1092         if conn.is_closed:
# -> 1093             conn.connect()
#    1094
#
# ~\AppData\Roaming\Python\Python39\site-packages\urllib3\connection.py in connect(self)
#     795
# --> 796             sock_and_verified = _ssl_wrap_socket_and_match_hostname(
#     797                 sock=sock,
#
# ...

# %%
import ssl
import os

print("SSL_CERT_FILE =", os.environ.get("SSL_CERT_FILE"))
print("REQUESTS_CA_BUNDLE =", os.environ.get("REQUESTS_CA_BUNDLE"))
print("GRPC_DEFAULT_SSL_ROOTS_FILE_PATH =", os.environ.get("GRPC_DEFAULT_SSL_ROOTS_FILE_PATH"))

print("\nDefault verify paths:")
print(ssl.get_default_verify_paths())
# Out:
# SSL_CERT_FILE = None
# REQUESTS_CA_BUNDLE = None
# GRPC_DEFAULT_SSL_ROOTS_FILE_PATH = None
#
# Default verify paths:
# DefaultVerifyPaths(cafile=None, capath=None, openssl_cafile_env='SSL_CERT_FILE', openssl_cafile='C:\\Program Files\\Common Files\\SSL/cert.pem', openssl_capath_env='SSL_CERT_DIR', openssl_capath='C:\\Program Files\\Common Files\\SSL/certs')

# %%
import requests

r = requests.get(
    "https://www.googleapis.com/discovery/v1/apis",
    verify=r"C:\Users\i025207\Desktop\fullCA.pem",
    timeout=10
)

print(r.status_code)
# Out:
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# ~\AppData\Roaming\Python\Python39\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     463             try:
# --> 464                 self._validate_conn(conn)
#     465             except (SocketTimeout, BaseSSLError) as e:
#
# ~\AppData\Roaming\Python\Python39\site-packages\urllib3\connectionpool.py in _validate_conn(self, conn)
#    1092         if conn.is_closed:
# -> 1093             conn.connect()
#    1094
#
# ~\AppData\Roaming\Python\Python39\site-packages\urllib3\connection.py in connect(self)
#     795
# --> 796             sock_and_verified = _ssl_wrap_socket_and_match_hostname(
#     797                 sock=sock,
#
# ...
